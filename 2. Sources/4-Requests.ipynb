# %% [markdown]
# ## Requests
#
# A biblioteca requests é um pacote Python que simplifica o trabalho com requisições HTTP.

# %%
import pandas as pd
import requests

# %% [markdown]
# ### Explorando o retorno do método get
#
# Métodos básicos de requisição HTTP:
# - GET: Solicita a representação de um recurso.
# - POST: Envio de dados para serem processados por um recurso.
# - PUT: Atualização de um recurso existente.
# - DELETE: Exclusão de um recurso.
#
# Status Codes
# - 2xx para sucesso
# - 3xx para redirecionamentos
# - 4xx para erros do cliente
# - 5xx para erros do servidor

# %%
api_url = "https://randomuser.me/api/?results=5"

# %%
response_api = requests.get(api_url, timeout=10)
response_api
# Out:
# <Response [200]>

# %%
print(response_api.cookies)
print(response_api.connection)
print(response_api.content)
# Out:
# <RequestsCookieJar[]>
# ...

# %%
response = response_api.json()
response
# Out:
# {'results': [{'gender': 'female',
#    'name': {'title': 'Mrs', 'first': 'Ella', 'last': 'Scott'},
#    'location': {'street': {'number': 6207, 'name': 'Richmond Road'},
#     'city': 'Aberdeen',
#     'state': 'Dyfed',
#     'country': 'United Kingdom',
#     'postcode': 'V20 0BS',
#     'coordinates': {'latitude': '-9.9509', 'longitude': '79.8445'},
#     'timezone': {'offset': '+3:00',
#      'description': 'Baghdad, Riyadh, Moscow, St. Petersburg'}},
#    'email': 'ella.scott@example.com',
#    'login': {'uuid': '5d689b05-e477-4f94-be42-73f1a3d0f39a',
#     'username': 'blackkoala281',
#     'password': 'donkey',
#     'salt': 'tCD8Jsn7',
#     'md5': '7374859ee5131f9efc59b65baf5d6801',
#     'sha1': 'd51ddca9ba9ab9f804e07fc1c2c5a37408f5f8bf',
#     'sha256': 'c4ad7014d506ae3e49e86aabf10d0ce50447337dd6084875cbe5db2907d25b8e'},
#    'dob': {'date': '1998-10-21T18:51:17.491Z', 'age': 27},
#    'registered': {'date': '2004-08-05T04:37:40.418Z', 'age': 21},
# ...

# %%
data = response['results']
df = pd.json_normalize(data)
df.head()
# Out:
#    gender                      email           phone            cell nat  \
# 0  female  belgin.wiertz@example.com   (0665) 945891   (06) 60755965  NL
# 1  female  sherry.hansen@example.com  (609) 217-3890  (859) 496-7163  US
# 2    male      ross.hill@example.com    041-679-1737    081-811-9613  IE
# 3  female  amber.coleman@example.com    016974 15403    07047 818692  GB
# 4  female  line.lefebvre@example.com  05-48-12-08-49  06-70-70-83-39  FR
#
#   name.title name.first name.last  location.street.number  \
# 0        Mrs     Belgin    Wiertz                    5019
# 1        Mrs     Sherry    Hansen                    3821
# 2         Mr       Ross      Hill                    4657
# 3        Mrs      Amber   Coleman                    6137
# 4        Mrs       Line  Lefebvre                    1509
#
#         location.street.name  ...  \
# 0       Dokter Keijserstraat  ...
# 1                   Royal Ln  ...
# 2                  Mill Lane  ...
# ...

# %%
cols = [s.replace('.', '_') for s in df.columns]
df.columns = cols
df.columns
# Out:
# Index(['gender', 'email', 'phone', 'cell', 'nat', 'name_title', 'name_first',
#        'name_last', 'location_street_number', 'location_street_name',
#        'location_city', 'location_state', 'location_country',
#        'location_postcode', 'location_coordinates_latitude',
#        'location_coordinates_longitude', 'location_timezone_offset',
#        'location_timezone_description', 'login_uuid', 'login_username',
#        'login_password', 'login_salt', 'login_md5', 'login_sha1',
#        'login_sha256', 'dob_date', 'dob_age', 'registered_date',
#        'registered_age', 'id_name', 'id_value', 'picture_large',
#        'picture_medium', 'picture_thumbnail'],
#       dtype='object')
